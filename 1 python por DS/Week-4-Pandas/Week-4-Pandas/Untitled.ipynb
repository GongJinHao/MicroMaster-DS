# %%
import pandas as pd
import numpy as np
espanol = pd.read_excel('./movielens/result_241_178.xlsx')
print(type(espanol))
espanol.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                                                 ruta  \
# 0  \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 1  \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 2  \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 3  \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 4  \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 5  \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 6  \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 7  \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 8  \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 9  \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
#
#                                             obtenido  \
# 0  Imposible porque la cifra o el símbolo ya esta...
# 1  Pedimos respeto y estamos resueltos a  hacerno...
# 2  Las consecuencias de su supresión son imprevis...
# 3  Se reúne la comisión delegada del gobierno par...
# 4  Posiblemente no pero sin duda la habría restad...
# ...

# %%
filter = espanol['corregido'].str.contains('.*\?\.*')
espanol['is_enie']=filter
espanol['is_enie'][:10]
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: is_enie, dtype: bool

# %%
espanol['recorregido'] = espanol['corregido'].str.replace('\?\.*', 'ñ', case  = False)
espanol[:20]
# Out:
#                                                  ruta  \
# 0   \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 1   \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 2   \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 3   \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 4   \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 5   \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 6   \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 7   \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 8   \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 9   \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 10  \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 11  \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 12  \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 13  \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 14  \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 15  \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# ...

# %%
filter2 = espanol['obtenido'].str.contains('.*\?\.*')
espanol['obtenido_is_enie']=filter2
espanol['obtenido'].head()
# Out:
# 7     Aquel episodio incluso acrecienta la popularid...
# 15    Cuatro a?os después la peque?a familia vuelve ...
# 24      En ba?o el biquini es una prenda imprescindible
# 25    Debe haber llegado muy peque?a a mazatlán con ...
# 30                        Ya no vi a la se?ora concluyó
# Name: obtenido, dtype: object

# %%
def llenar_NaN():
    
espanol['recorregido2'] = espanol['recorregido'].str.replace('T', '' , case  = True)
espanol[:50]
# Out:
#                                                  ruta  \
# 0   \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 1   \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 2   \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 3   \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 4   \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 5   \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 6   \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 7   \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 8   \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 9   \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 10  \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 11  \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 12  \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 13  \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 14  \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# 15  \\10.10.8.124\最新整理的自有数据\数据提取——李昺\赵鹏\西班牙语音\新建文件...
# ...

# %%
espanol.to_excel('file_name0.xlsx')
